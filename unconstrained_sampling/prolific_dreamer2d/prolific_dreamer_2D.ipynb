# %% [markdown]
# ### 2D Implementation of paper [ProlificDreamer: High-Fidelity and Diverse Text-to-3D Generation with Variational Score Distillation](https://arxiv.org/abs/2305.16213)

# %%
### clone the repo
# !git clone https://github.com/yuanzhi-zhu/prolific_dreamer2d.git
# Out:
# Cloning into 'prolific_dreamer2d'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 48 (delta 24), reused 34 (delta 11), pack-reused 0
# Unpacking objects: 100% (48/48), 11.70 MiB | 12.70 MiB/s, done.

# %%
# !nvidia-smi
# Out:
# Mon Jul  3 20:21:06 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
cd prolific_dreamer2d
# Out:
# /home/nicolas/prolific_dreamer2d
# /home/nicolas/anaconda3/envs/stable-dif/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install --upgrade pip
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# ...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# ...
#   Cloning https://github.com/huggingface/diffusers (to revision 1994dbcb5e62bd8d0c60e5d5d6bf4b580653c74c) to /tmp/pip-install-mi3kpert/diffusers_94b4678358d2421a82ed506cbf7cfc8d
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-install-mi3kpert/diffusers_94b4678358d2421a82ed506cbf7cfc8d
#   Running command git rev-parse -q --verify 'sha^1994dbcb5e62bd8d0c60e5d5d6bf4b580653c74c'
#   Running command git fetch -q https://github.com/huggingface/diffusers 1994dbcb5e62bd8d0c60e5d5d6bf4b580653c74c
#   Running command git checkout -q 1994dbcb5e62bd8d0c60e5d5d6bf4b580653c74c
# ...

# %%
# !bash run.sh
# Out:
# 2023-07-03 20:29:05.531330: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/prolific_dreamer2d/model_utils.py:113: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   betas = torch.tensor(betas)
# /content/prolific_dreamer2d/prolific_dreamer2d.py:253: FutureWarning: Accessing config attribute `in_channels` directly via 'UNet2DConditionModel' object attribute is deprecated. Please access 'in_channels' over 'UNet2DConditionModel's config object instead, e.g. 'unet.config.in_channels'.
#   particles = torch.randn((args.batch_size, unet.in_channels, args.height // 8, args.width // 8))
# Total number of trainable parameters in particles: 16384; number of particles: 1
# number of trainable parameters of phi model in optimizer: 829952
# ...

# %%
import pandas as pd

columns = ['guidance', 'SDS', 'NFSD', 'ProlificDreamer', 'NFSD with repulsion']
df_similarity = pd.DataFrame(columns=columns)
df_aesthetic = pd.DataFrame(columns=columns)

# %%
df_similarity.loc[0] = ['7.5', 0, 0, 0.77, 0.64]
df_aesthetic.loc[0] = ['7.5', 0, 0, 5.18, 5.37]
# Out:
# Empty DataFrame
# Columns: [config, SDS, NFSD, ProlificDreamr, NFSD with repulsion]
# Index: []
